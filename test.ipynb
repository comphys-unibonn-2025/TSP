# %%
import numpy as np
import tsp_backend
from matplotlib.path import Path
import matplotlib.pyplot as plt

p1 = np.array([0, 0])
p2 = np.array([1, 0])

tsp_backend.metric(p1, p2)
# Out:
# np.float64(1.0)

# %%
nodes = np.array([[0, 0], [1, 0], [1, 1], [0, 1]])

tsp_backend.make_distance_matrix(nodes)
# Out:
# array([[0.        , 1.        , 1.41421356, 1.        ],
#        [1.        , 0.        , 1.        , 1.41421356],
#        [1.41421356, 1.        , 0.        , 1.        ],
#        [1.        , 1.41421356, 1.        , 0.        ]])

# %%
a = 1
b = 1

(a + b) * (1 if (a == b) else 0)
# Out:
# 2

# %%
tsp_backend.plot_tsp_route(nodes, np.array([0, 1, 2, 3]), traffic_polygon=np.array([[0.3, 0.3], [0.7, 0.3], [0.7, 0.7], [0.3, 0.7]]), output_path="test.png")
